# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import requests
from matplotlib.ticker import FuncFormatter

# %%
pe = pd.read_csv('PERSPE 2.csv')

# %%
pe.head()
# Out:
#                                            name  year     capital          in  \
# 0              Apollo Asia Opportunity Fund, LP  2007    50000000    50000000
# 1        Apollo Credit Opportunity Fund I, L.P.  2008  1000000000  1225580618
# 2  Apollo European Principal Finance Fund, L.P.  2008    88853413   165208888
# 3               Apollo Investment Fund IV, L.P.  1998   150000000   154312417
# 4                Apollo Investment Fund IX, L.P  2019   550000000    50239055
#
#           out      remain     irr multiple
# 0    44702747    44702747  -0.024     0.9x
# 1  3163711754  3178591155   0.274     2.6x
# 2   200323914   200668192   0.119     1.2x
# 3   254289011   254460913   0.085     1.6x
# 4        5695    41252044   N/M 1    N/M 1

# %%
pe = pe.replace('N/M 1', 'NaN').dropna(subset=['remain','multiple'])

# %%
pe.head()
# Out:
#                                            name  year     capital          in  \
# 0              Apollo Asia Opportunity Fund, LP  2007    50000000    50000000
# 1        Apollo Credit Opportunity Fund I, L.P.  2008  1000000000  1225580618
# 2  Apollo European Principal Finance Fund, L.P.  2008    88853413   165208888
# 3               Apollo Investment Fund IV, L.P.  1998   150000000   154312417
# 4                Apollo Investment Fund IX, L.P  2019   550000000    50239055
#
#           out      remain     irr multiple
# 0    44702747    44702747  -0.024     0.9x
# 1  3163711754  3178591155   0.274     2.6x
# 2   200323914   200668192   0.119     1.2x
# 3   254289011   254460913   0.085     1.6x
# 4        5695    41252044     NaN      NaN

# %%
pe.dropna(inplace=True)

# %%
pe
# Out:
#                                             name  year     capital  \
# 0               Apollo Asia Opportunity Fund, LP  2007    50000000
# 1         Apollo Credit Opportunity Fund I, L.P.  2008  1000000000
# 2   Apollo European Principal Finance Fund, L.P.  2008    88853413
# 3                Apollo Investment Fund IV, L.P.  1998   150000000
# 4                 Apollo Investment Fund IX, L.P  2019   550000000
# ..                                           ...   ...         ...
# 83                           TPG Growth IV, L.P.  2018    75000000
# 84                         TPG Partners IV, L.P.  2003   200000000
# 85                          TPG Partners V, L.P.  2006   600000000
# 86                         TPG Partners VI, L.P.  2008   825000000
# 87                                TPG STAR, L.P.  2007   150000000
#
#             in         out      remain     irr multiple
# 0     50000000    44702747    44702747  -0.024     0.9x
# ...
